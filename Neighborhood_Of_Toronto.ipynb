# %% [markdown]
# <h3>Part 1 : Create and Clean Data Frame</h3>

# %%
#importing numpy and pandas
import numpy as np
import pandas as pd

# %%
#import matplotlib
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
#web scraping using Pandas
list_of_tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# %%
#checking datatype
type(list_of_tables)
# Out:
# list

# %%
#Getting the Dataframe which consists of relevant data
df = list_of_tables[0]

# %%
df.head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
#to check how many rows are null
df.isnull().sum()
# Out:
# Postal code      0
# Borough          0
# Neighborhood    77
# dtype: int64

# %%
df.describe()
# Out:
#        Postal code       Borough Neighborhood
# count          180           180          103
# unique         180            11           98
# top            M2M  Not assigned    Downsview
# freq             1            77            4

# %%
'''
to drop rows containing "Not assigned" by dropping rows with null value in "Neighborhood" column as 
Neighborhood couldn't exist withot Borough.
'''
df.dropna(inplace = True)

# %%
df.head()
# Out:
#   Postal code           Borough                                  Neighborhood
# 2         M3A        North York                                     Parkwoods
# 3         M4A        North York                              Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5         M6A        North York             Lawrence Manor / Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %%
df.reset_index(inplace = True, drop = True)

# %%
df.describe()
# Out:
#        Postal code     Borough Neighborhood
# count          103         103          103
# unique         103          10           98
# top            M2M  North York    Downsview
# freq             1          24            4

# %%
df.head()
# Out:
#   Postal code           Borough                                  Neighborhood
# 0         M3A        North York                                     Parkwoods
# 1         M4A        North York                              Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park / Harbourfront
# 3         M6A        North York             Lawrence Manor / Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %%
#replacing "/" with "," in "Neighborhood" Column
df['Neighborhood'] = df['Neighborhood'].str.replace('/',',')
df.head()
# Out:
#   Postal code           Borough                                  Neighborhood
# 0         M3A        North York                                     Parkwoods
# 1         M4A        North York                              Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park , Harbourfront
# 3         M6A        North York             Lawrence Manor , Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government

# %%
#shape of dataframe
print("Shape of DataFrame is : ",df.shape)
# Out:
# Shape of DataFrame is :  (103, 3)

# %% [markdown]
# <h3>Part 2 : Fetching Latitude and Longitude</h3>

# %%
# i tried a lot for using Geocoders but it was giving issue, hence used .csv file as recommended.
lat_lng = pd.read_csv("http://cocl.us/Geospatial_data")

# %%
lat_lng.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#user merge to merge df dataframe and lat_lng dataframe. 
df = df.merge(lat_lng, how = 'left', left_on = 'Postal code', right_on = 'Postal Code')

# %%
#dropped "Postal Code" column from lat_lng dataframe as it was redundant.
df.drop('Postal Code', axis = 1, inplace = True)

# %%
df.head()
# Out:
#   Postal code           Borough                                  Neighborhood  \
# 0         M3A        North York                                     Parkwoods
# 1         M4A        North York                              Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park , Harbourfront
# 3         M6A        North York             Lawrence Manor , Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# <h3>Part 3 : Exploring Neighborhoods in Toronto</h3>

# %%
#neighborhoods in Toronto
df_toronto = df[df['Borough'].str.contains('Toronto')].reset_index(drop = True)

# %%
df_toronto.head()
# Out:
#   Postal code           Borough                                  Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park , Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
# 2         M5B  Downtown Toronto                      Garden District, Ryerson
# 3         M5C  Downtown Toronto                                St. James Town
# 4         M4E      East Toronto                                   The Beaches
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.676357 -79.293031

# %%
print('Shape of df_toronto: ',df_toronto.shape)
# Out:
# Shape of df_toronto:  (39, 5)

# %%
#import Geopy
import geopy

# %%
#import Nominatim
from geopy.geocoders import Nominatim

# %%
#fetching latitiude and longitude of Toronto
geo = Nominatim(user_agent = 'my_application')
location_toronto = geo.geocode('Toronto')
lat = location_toronto.latitude
long = location_toronto.longitude
print('Graphical coordinates of Toronto are {} and {}.'.format(lat,long))
# Out:
# Graphical coordinates of Toronto are 43.6534817 and -79.3839347.

# %%
#import Folium
import folium

# %%
#map visualization of neighborhood in Toronto
map_toronto = folium.Map(location = [lat,long], zoom_start= 11.5)

for lat,lng,label in zip(df_toronto['Latitude'],df_toronto['Longitude'],df_toronto['Neighborhood']):
    label = folium.Popup(label,parse_html = True )
    folium.CircleMarker(
    [lat,lng],
    radius = 5,
    popup = label,
    color = 'blue',
    fill = True,    
    fill_color = '#3186CC',
    fill_opacity = 0.7,
    parse_html = False).add_to(map_toronto)

    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h4>Foursquare Credentials</h4>

# %%
client_id = '3EXJEPE3HIZJR234GXTVUF0IAMWDGGURTMLNSL3AW3QULKMJ'
client_secret = 'TMQZJAWQKISWFZMI3NAFDVMX4J5GNJNKTNWT1TPLNHPZKCIG'
version = '20200411'

# %% [markdown]
# Fetching top 10 venues near <b>St. James Town</b> Neighborhood within 200 meters.

# %%
limit = 10
radius = 200

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&limit={}&radius={}'.format(
        client_id,
        client_secret,
        version,
        df_toronto.loc[3,'Latitude'],
        df_toronto.loc[3,'Longitude'],
        limit,
        radius)

# %%
#import requests
import requests as rq

# %%
#fetching result for St.James Town
st_james_town_result = rq.get(url).json()

# %%
#analyzing the result
st_james_town_result
# Out:
# {'meta': {'code': 200, 'requestId': '5e93111c660a9f001bf7926b'},
#  'response': {'headerLocation': 'St. Lawrence',
#   'headerFullLocation': 'St. Lawrence, Toronto',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 9,
#   'suggestedBounds': {'ne': {'lat': 43.6532939018, 'lng': -79.37293481442669},
#    'sw': {'lat': 43.6496938982, 'lng': -79.37790098557332}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '574ad72238fa943556d93b8e',
#        'name': 'Gyu-Kaku Japanese BBQ',
#        'location': {'address': '81 Church St',
#         'crossStreet': 'at Adelaide St E',
#         'lat': 43.651422275497914,
#         'lng': -79.37504693687086,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.651422275497914,
#           'lng': -79.37504693687086}],
#         'distance': 30,
#         'postalCode': 'M5C 2G2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['81 Church St (at Adelaide St E)',
#          'Toronto ON M5C 2G2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-574ad72238fa943556d93b8e-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b49183ff964a520a46526e3',
#        'name': 'Terroni',
#        'location': {'address': '57 Adelaide St. E',
#         'crossStreet': 'at Church St.',
#         'lat': 43.650927,
#         'lng': -79.375602,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650927,
#           'lng': -79.375602}],
#         'distance': 64,
#         'postalCode': 'M5C 1K6',
#         'cc': 'CA',
#         'neighborhood': 'St. Lawrence',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['57 Adelaide St. E (at Church St.)',
#          'Toronto ON M5C 1K6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b49183ff964a520a46526e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad8ad9bf964a520a51321e3',
#        'name': 'Pearl Diver',
#        'location': {'address': '100 Adelaide St E',
#         'crossStreet': 'Jarvis',
#         'lat': 43.651481290733734,
#         'lng': -79.37359954211877,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.651481290733734,
#           'lng': -79.37359954211877}],
#         'distance': 146,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['100 Adelaide St E (Jarvis)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '99375482'}},
#       'referralId': 'e-0-4ad8ad9bf964a520a51321e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '583f54320923922e8141d360',
#        'name': 'Crepe TO',
#        'location': {'address': '52 Church Street',
#         'lat': 43.650063279511016,
#         'lng': -79.37458664523871,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650063279511016,
#           'lng': -79.37458664523871}],
#         'distance': 172,
#         'postalCode': 'M5C 3C8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['52 Church Street',
#          'Toronto ON M5C 3C8',
#          'Canada']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f2',
#          'name': 'Creperie',
#          'pluralName': 'Creperies',
#          'shortName': 'Creperie',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/creperie_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-583f54320923922e8141d360-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57963897498e6873394a559d',
#        'name': 'Versus Coffee',
#        'location': {'address': '70 Adelaide St E',
#         'crossStreet': 'at Church St',
#         'lat': 43.65121343781903,
#         'lng': -79.37523564828548,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65121343781903,
#           'lng': -79.37523564828548}],
#         'distance': 34,
#         'cc': 'CA',
#         'neighborhood': 'St. Lawrence',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['70 Adelaide St E (at Church St)',
#          'Toronto ON',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57963897498e6873394a559d-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b999927f964a5207c8635e3',
#        'name': 'NAMI',
#        'location': {'address': '55 Adelaide Street East',
#         'crossStreet': 'at Church street',
#         'lat': 43.650853361785124,
#         'lng': -79.37588746641697,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650853361785124,
#           'lng': -79.37588746641697}],
#         'distance': 80,
#         'postalCode': 'M5C 1K6',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['55 Adelaide Street East (at Church street)',
#          'Toronto ON M5C 1K6',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b999927f964a5207c8635e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad4c05ef964a520a9f620e3',
#        'name': 'St James Anglican Cathedral',
#        'location': {'address': '65 Church St.',
#         'crossStreet': 'at King St. E',
#         'lat': 43.650109744784004,
#         'lng': -79.37429172248066,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650109744784004,
#           'lng': -79.37429172248066}],
#         'distance': 178,
#         'postalCode': 'M5C 2E9',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['65 Church St. (at King St. E)',
#          'Toronto ON M5C 2E9',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad4c05ef964a520a9f620e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4e764af964a5209cee26e3',
#        'name': 'HI-Toronto Hostel',
#        'location': {'address': '76 Church St',
#         'crossStreet': 'King Subway Station',
#         'lat': 43.650623213878255,
#         'lng': -79.37519039641123,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.650623213878255,
#           'lng': -79.37519039641123}],
#         'distance': 98,
#         'postalCode': 'M5C 2G1',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['76 Church St (King Subway Station)',
#          'Toronto ON M5C 2G1',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33098899'}},
#       'referralId': 'e-0-4b4e764af964a5209cee26e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c00007498e27a169aed821',
#        'name': '120 Diner',
#        'location': {'address': '120 Church St',
#         'crossStreet': 'Richmond',
#         'lat': 43.65213913494571,
#         'lng': -79.37541831809602,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.65213913494571,
#           'lng': -79.37541831809602}],
#         'distance': 71,
#         'postalCode': 'M5C 2G8',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['120 Church St (Richmond)',
#          'Toronto ON M5C 2G8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53c00007498e27a169aed821-8'}]}]}}

# %% [markdown]
# Creating a function that will help to fetch data for all the Neighborhoods.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            client_id, 
            client_secret, 
            version, 
            lat, 
            lng, 
            radius, 
            limit)
            
        # make the GET request
        venues_results = rq.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in venues_results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
#to run above funtion on each Neighborhood
venues = getNearbyVenues(names=df_toronto['Neighborhood'],
                                   latitudes=df_toronto['Latitude'],
                                   longitudes=df_toronto['Longitude']
                                  )

# %%
#Check the shape and Head
print("Shape of Venues DF: ",venues.shape)
venues.head()
# Out:
# Shape of Venues DF:  (346, 7)
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park , Harbourfront               43.65426              -79.360636
# 1  Regent Park , Harbourfront               43.65426              -79.360636
# 2  Regent Park , Harbourfront               43.65426              -79.360636
# 3  Regent Park , Harbourfront               43.65426              -79.360636
# 4  Regent Park , Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4      Morning Glory Cafe       43.653947       -79.361149
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4       Breakfast Spot

# %%
#Check the venue category
venues['Venue Category'].value_counts()
# Out:
# Coffee Shop                      26
# Café                             24
# Restaurant                       17
# Park                             15
# Italian Restaurant               12
# Pub                               9
# Gym                               7
# Mexican Restaurant                6
# Bakery                            6
# Dessert Shop                      6
# Bar                               5
# Pizza Place                       5
# Brewery                           5
# Ice Cream Shop                    5
# Sushi Restaurant                  5
# Breakfast Spot                    5
# American Restaurant               4
# Middle Eastern Restaurant         4
# Burrito Place                     4
# Cocktail Bar                      4
# Yoga Studio                       4
# Greek Restaurant                  4
# Gastropub                         4
# Tea Room                          4
# Vegetarian / Vegan Restaurant     4
# Bookstore                         4
# Grocery Store                     3
# Liquor Store                      3
# Indian Restaurant                 3
# Neighborhood                      3
#                                  ..
# Bank                              1
# Food Truck                        1
# Lake                              1
# Organic Grocery                   1
# Movie Theater                     1
# Convenience Store                 1
# Airport Gate                      1
# Boutique                          1
# Dance Studio                      1
# Garden Center                     1
# Dog Run                           1
# Flea Market                       1
# Food                              1
# Sports Bar                        1
# Deli / Bodega                     1
# Korean Restaurant                 1
# Skating Rink                      1
# Eastern European Restaurant       1
# Swim School                       1
# Wine Bar                          1
# Garden                            1
# Caribbean Restaurant              1
# Vietnamese Restaurant             1
# Bus Line                          1
# Fountain                          1
# Performing Arts Venue             1
# Salad Place                       1
# Gay Bar                           1
# Plane                             1
# Candy Store                       1
# Name: Venue Category, Length: 121, dtype: int64

# %%
#Onehot encoding using Get_dummies
toronto_onehot = pd.get_dummies(venues[['Venue Category']],prefix = "", prefix_sep = "")

# %%
toronto_onehot['Neighborhood'] = venues['Neighborhood']

# %%
#grouping on Basis of Neighborhood
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %%
toronto_grouped.shape
# Out:
# (39, 121)

# %% [markdown]
# Let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park          Cocktail Bar
# 1     Brockton , Parkdale Village , Exhibition Place           Coffee Shop
# 2              Business reply mail Processing CentrE           Pizza Place
# 3  CN Tower , King and Spadina , Railway Lands , ...        Airport Lounge
# 4                                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue   3rd Most Common Venue       4th Most Common Venue  \
# 0        Farmers Market            Concert Hall                      Museum
# 1                  Café  Furniture / Home Store                   Pet Store
# 2         Auto Workshop           Garden Center                  Restaurant
# 3               Airport                     Bar          Airport Food Court
# 4             Gastropub      Italian Restaurant  Modern European Restaurant
#
#        5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                 Restaurant          Liquor Store           Coffee Shop
# 1             Breakfast Spot                   Gym    Italian Restaurant
# 2              Burrito Place            Skate Park               Brewery
# 3               Airport Gate      Airport Terminal              Boutique
# 4  Middle Eastern Restaurant       Bubble Tea Shop                  Park
#
#   8th Most Common Venue 9th Most Common Venue         10th Most Common Venue
# 0                  Park     French Restaurant  Vegetarian / Vegan Restaurant
# 1          Climbing Gym                   Bar                   Dessert Shop
# 2        Farmers Market  Fast Food Restaurant                     Comic Shop
# 3                 Plane       Harbor / Marina            Distribution Center
# 4                  Food      Department Store         Furniture / Home Store

# %%
#import KMeans
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 1, 1, 1, 1, 4, 0, 4, 1, 1])

# %% [markdown]
# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df_toronto

toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head()
# Out:
#   Postal code           Borough                                  Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park , Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park , Ontario Provincial Government
# 2         M5B  Downtown Toronto                      Garden District, Ryerson
# 3         M5C  Downtown Toronto                                St. James Town
# 4         M4E      East Toronto                                   The Beaches
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.654260 -79.360636               1        Breakfast Spot
# 1  43.662301 -79.389494               1           Coffee Shop
# 2  43.657162 -79.378937               1           Music Venue
# 3  43.651494 -79.375418               1           Coffee Shop
# 4  43.676357 -79.293031               1                 Trail
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Spa                Bakery                   Pub
# 1              Beer Bar   Distribution Center    Mexican Restaurant
# 2                 Plaza          Burger Joint         Burrito Place
# 3                   Gym    Italian Restaurant            Restaurant
# 4                   Pub     Health Food Store           Yoga Studio
#
#        5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                 Restaurant           Coffee Shop   Distribution Center
# 1                   Creperie                  Park         Burrito Place
# 2           Ramen Restaurant                  Café              Tea Room
# 3  Middle Eastern Restaurant             BBQ Joint   Japanese Restaurant
# 4        Distribution Center            Comic Shop          Concert Hall
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0         Historic Site                  Park      Fish & Chips Shop
# 1           Yoga Studio   Arts & Crafts Store       Asian Restaurant
# 2               Theater        Clothing Store             Comic Shop
# 3            Food Truck        Cosmetics Shop              Gastropub
# 4     Convenience Store        Cosmetics Shop               Creperie

# %% [markdown]
# Visualizing Clusters on basis of KMEANS clustering

# %%
# create map
map_clusters = folium.Map(location=[lat, long], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neigh, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(neigh) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
